# %%
import pandas as pd
df = pd.read_csv('dataset.csv')

dt
# Out:
#                 timestamp    turno operador_id maquina_id producto_id  \
# 0     2023-01-01 00:00:00    Noche       OP_16        M_8        P_14
# 1     2023-01-01 01:00:00  MaÃ±ana       OP_18        M_8        P_12
# 2     2023-01-01 02:00:00    Noche        OP_5        M_7        P_14
# 3     2023-01-01 03:00:00    Noche        OP_4        M_6        P_15
# 4     2023-01-01 04:00:00  MaÃ±ana       OP_13        M_6         P_7
# ...                   ...      ...         ...        ...         ...
# 5995  2023-09-07 19:00:00  MaÃ±ana        OP_7        M_9         P_2
# 5996  2023-09-07 20:00:00    Tarde       OP_16        M_9         P_1
# 5997  2023-09-07 21:00:00    Noche        OP_3        M_7        P_11
# 5998  2023-09-07 22:00:00    Tarde        OP_7        M_6         P_1
# 5999  2023-09-07 23:00:00    Tarde        OP_6        M_3         P_1
#
#       temperatura  vibraciÃ³n    humedad  tiempo_ciclo fallo_detectado  \
# 0       74.200401    0.000000  45.209387    106.356684              No
# 1       85.886727    0.481294  52.623286    106.147220             SÃ­
# 2       81.293588    0.446638  48.538203    122.517733              No
# 3       75.697975    0.576969  55.597781    123.641235              No
# 4       69.887504    0.716240  63.837428    126.276992              No
# ...           ...         ...        ...           ...             ...
# 5995    69.566198    0.359394  31.452299    110.456904              No
# 5996    72.509325    0.387216  45.429609    145.575235              No
# 5997    72.452851    0.551448  27.774960     74.620786              No
# 5998    74.236404    0.429883  41.528769    111.656062              No
# 5999    70.501856    0.612991  59.584130    119.290237              No
#
#       tipo_fallo  cantidad_producida  unidades_defectuosas  \
# 0      Sin_fallo                 108                     3
# 1     ElÃ©ctrico                  86                     2
# 2      Sin_fallo                 103                     0
# 3      Sin_fallo                 104                     2
# 4      Sin_fallo                 119                     1
# ...          ...                 ...                   ...
# 5995   Sin_fallo                  85                     6
# 5996   Sin_fallo                 109                     4
# 5997   Sin_fallo                 109                     0
# 5998   Sin_fallo                 101                     3
# 5999   Sin_fallo                  82                     2
#
#       eficiencia_porcentual  consumo_energia  paradas_programadas  \
# 0                 87.021704        13.131580                    0
# 1                 81.200758        13.348221                    0
# 2                 79.104477        15.461715                    3
# 3                 84.176537        16.156453                    4
# 4                 93.535084        12.573939                    0
# ...                     ...              ...                  ...
# 5995              83.359399        17.467713                    1
# 5996              87.847138        11.850616                    0
# 5997               0.000000         0.000000                    1
# 5998              87.225639        17.073040                    0
# 5999              75.578950        13.310307                    2
#
#       paradas_imprevistas         observaciones
# 0                       1                   NaN
# 1                       0                   NaN
# 2                       0     OperaciÃ³n normal
# 3                       0                   NaN
# 4                       0     OperaciÃ³n normal
# ...                   ...                   ...
# 5995                    0                   NaN
# 5996                    0                   NaN
# 5997                    1  Revisar calibraciÃ³n
# 5998                    0                   NaN
# 5999                    0     OperaciÃ³n normal
#
# [6000 rows x 18 columns]

# %%
# Reemplazo en la columna "turno"
df["turno"] = df["turno"].replace({
    "MaÃ±ana": "Mañana",
    "Tarde": "Tarde",
    "Noche": "Noche"
})

# Reemplazo en la columna "tipo_fallo"
df["tipo_fallo"] = df["tipo_fallo"].replace({
    "ElÃ©ctrico": "Eléctrico",
    "MecÃ¡nico": "Mecánico",
    "Revisar calibraciÃ³n": "Revisar calibración",
    "Ninguno": "Ninguno"
})

# Reemplazo en la columna "observaciones"
df["observaciones"] = df["observaciones"].replace({
    "OperaciÃ³n normal": "Operación normal",
    "Sobrecalentamiento": "Sobrecalentamiento"
})

# Si tienes una columna de respuestas como "sí", corregimos eso también:
df = df.replace("SÃ­", "Sí")  # Aplica globalmente a todo el DataFrame

# Revisa que ya estén corregidos
print(df["turno"].unique())
print(df["tipo_fallo"].unique())
print(df["observaciones"].unique())

# Eliminar espacios antes y después, y reemplazar errores de codificación comunes
df = df.applymap(lambda x: x.strip() if isinstance(x, str) else x)

# Reemplazar texto mal codificado en todo el DataFrame
df = df.replace({
    "Revisar calibraciÃ³n": "Revisar calibración",
    "CalibraciÃ³n": "Calibración",
    "SÃ­": "Sí",
    "MaÃ±ana": "Mañana",
    "ElÃ©ctrico": "Eléctrico",
    "MecÃ¡nico": "Mecánico",
    "OperaciÃ³n normal": "Operación normal"
}, regex=False)

df.fillna("No registra", inplace=True)
# Out:
# ['Noche' 'Mañana' 'Tarde']
# ['Sin_fallo' 'Eléctrico' 'Mecánico' 'Otro']
# [nan 'Operación normal' 'Revisar calibraciÃ³n' 'Ruido inusual']
# C:\Users\cenit\AppData\Local\Temp\ipykernel_4168\3346340678.py:31: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: x.strip() if isinstance(x, str) else x)

# %%
df
# Out:
#                 timestamp   turno operador_id maquina_id producto_id  \
# 0     2023-01-01 00:00:00   Noche       OP_16        M_8        P_14
# 1     2023-01-01 01:00:00  Mañana       OP_18        M_8        P_12
# 2     2023-01-01 02:00:00   Noche        OP_5        M_7        P_14
# 3     2023-01-01 03:00:00   Noche        OP_4        M_6        P_15
# 4     2023-01-01 04:00:00  Mañana       OP_13        M_6         P_7
# ...                   ...     ...         ...        ...         ...
# 5995  2023-09-07 19:00:00  Mañana        OP_7        M_9         P_2
# 5996  2023-09-07 20:00:00   Tarde       OP_16        M_9         P_1
# 5997  2023-09-07 21:00:00   Noche        OP_3        M_7        P_11
# 5998  2023-09-07 22:00:00   Tarde        OP_7        M_6         P_1
# 5999  2023-09-07 23:00:00   Tarde        OP_6        M_3         P_1
#
#       temperatura  vibraciÃ³n    humedad  tiempo_ciclo fallo_detectado  \
# 0       74.200401    0.000000  45.209387    106.356684              No
# 1       85.886727    0.481294  52.623286    106.147220              Sí
# 2       81.293588    0.446638  48.538203    122.517733              No
# 3       75.697975    0.576969  55.597781    123.641235              No
# 4       69.887504    0.716240  63.837428    126.276992              No
# ...           ...         ...        ...           ...             ...
# 5995    69.566198    0.359394  31.452299    110.456904              No
# 5996    72.509325    0.387216  45.429609    145.575235              No
# 5997    72.452851    0.551448  27.774960     74.620786              No
# 5998    74.236404    0.429883  41.528769    111.656062              No
# 5999    70.501856    0.612991  59.584130    119.290237              No
#
#      tipo_fallo  cantidad_producida  unidades_defectuosas  \
# 0     Sin_fallo                 108                     3
# 1     Eléctrico                  86                     2
# 2     Sin_fallo                 103                     0
# 3     Sin_fallo                 104                     2
# 4     Sin_fallo                 119                     1
# ...         ...                 ...                   ...
# 5995  Sin_fallo                  85                     6
# 5996  Sin_fallo                 109                     4
# 5997  Sin_fallo                 109                     0
# 5998  Sin_fallo                 101                     3
# 5999  Sin_fallo                  82                     2
#
#       eficiencia_porcentual  consumo_energia  paradas_programadas  \
# 0                 87.021704        13.131580                    0
# 1                 81.200758        13.348221                    0
# 2                 79.104477        15.461715                    3
# 3                 84.176537        16.156453                    4
# 4                 93.535084        12.573939                    0
# ...                     ...              ...                  ...
# 5995              83.359399        17.467713                    1
# 5996              87.847138        11.850616                    0
# 5997               0.000000         0.000000                    1
# 5998              87.225639        17.073040                    0
# 5999              75.578950        13.310307                    2
#
#       paradas_imprevistas        observaciones
# 0                       1          No registra
# 1                       0          No registra
# 2                       0     Operación normal
# 3                       0          No registra
# 4                       0     Operación normal
# ...                   ...                  ...
# 5995                    0          No registra
# 5996                    0          No registra
# 5997                    1  Revisar calibración
# 5998                    0          No registra
# 5999                    0     Operación normal
#
# [6000 rows x 18 columns]

# %%
df.to_csv("Datos_Talento_Limpio_UTF8.csv", index=False, encoding="utf-8-sig")
